# %% [markdown]
# # 01 - Variables
#
# A **variable** is a name that holds a value. That's it.
#
# ```python
# name = "something"
# ```
#
# The name on the left, the value on the right.

# %%
poem = "The Raven"
print(poem)

# %%
line = "Once upon a midnight dreary, while I pondered, weak and weary"
print(line)

# %% [markdown]
# You can use variables together:

# %%
author = "Edgar Allan Poe"

print(f"{poem} by {author}")
print(f"First line: {line}")

# %% [markdown]
# ---
#
# ## Try it
#
# Create variables for another poem and print them:

# %%
# Your code here
